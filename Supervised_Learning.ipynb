# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/refs/heads/master/BostonHousing.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
input_data = df.iloc[:,:-1]
output_data = df["tax"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size = 0.25)

# %%
x_test
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 501   0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 186   0.05602   0.0   2.46     0  0.488  7.831  53.6  3.1992    3  193
# 389   8.15174   0.0  18.10     0  0.700  5.390  98.9  1.7281   24  666
# 231   0.46296   0.0   6.20     0  0.504  7.412  76.9  3.6715    8  307
# 497   0.26838   0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 417  25.94060   0.0  18.10     0  0.679  5.304  89.1  1.6475   24  666
# 268   0.54050  20.0   3.97     0  0.575  7.470  52.6  2.8720    5  264
# 179   0.05780   0.0   2.46     0  0.488  6.980  58.4  2.8290    3  193
# 322   0.35114   0.0   7.38     0  0.493  6.041  49.9  4.7211    5  287
# 422  12.04820   0.0  18.10     0  0.614  5.648  87.6  1.9512   24  666
#
#      ptratio       b  lstat
# 501     21.0  391.99   9.67
# 186     17.8  392.63   4.45
# ...

# %%
y_train
# Out:
# 222    307
# 43     233
# 326    287
# 490    711
# 284    285
#       ...
# 275    254
# 479    666
# 248    330
# 225    307
# 139    437
# Name: tax, Length: 379, dtype: int64

# %%
x_train.shape , y_train.shape
# Out:
# ((379, 13), (379,))

# %%
x_test.shape , y_test.shape
# Out:
# ((127, 13), (127,))

# %%
Regression Analysis

# %%
Linear Regression ALgorithm (Simple Linear)

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/sachin365123/CSV-files-for-Data-Science-and-Machine-Learning/refs/heads/main/tips.csv")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
data = {"cgpa":["6.89","5.12","7.82"], "package":["3.26","1.98","3.25"]}

# %%
#df2 = pd.DataFrame(data)
#df2
# Out:
#    cgpa package
# 0  6.89    3.26
# 1  5.12    1.98
# 2  7.82    3.25

# %%
df1.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Salary_Data.csv")
df2
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sns.scatterplot(x = "YearsExperience",y="Salary",data = df2)
plt.show()

# %%
x = df2[["YearsExperience"]]
y = df2[["Salary"]]

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y = m*x+c

# %%
lr.coef_
# Out:
# array([[9423.81532303]])

# %%
lr.intercept_
# Out:
# array([25321.58301178])

# %%
y = 9423.81532303*x-

# %%
lr.score(x_test,y_test)*100
# Out:
# 90.24461774180497

# %%
 lr.predict([[1.1]])
# Out:
# C:\Users\Ali Shah\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[35687.77986711]])

# %%
 lr.predict([[1.3]])
# Out:
# C:\Users\Ali Shah\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[37572.54293172]])

# %%
 9423.81532303*1.1-25321.58301178
# Out:
# -14955.386156446999

# %%
y_prd = lr.predict(x)

# %%
sns.scatterplot(x = "YearsExperience",y="Salary",data = df2 )
plt.plot(df2["YearsExperience"],y_prd, c="red", )
plt.legend(["org","predict line"])      
plt.savefig("predict.jpg")
plt.show()

# %%
Multiple Linear (Regression)

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/Pranjali1049/Salary_Prediction/refs/heads/main/Salary_Data.csv")
df3
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df3.shape
# Out:
# (6704, 6)

# %%
df3.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
sns.pairplot(data =df3)
plt.show()

# %%
x = df3.iloc[:,:-1]
x
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience
# 0                     5.0
# 1                     3.0
# 2                    15.0
# 3                     7.0
# 4                    20.0
# ...                   ...
# 6699                 20.0
# ...

# %%
x = df3.iloc[:,:-1]
y = df3["Salary"]

# %%
df3.shape
# Out:
# (6704, 6)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
Polynomial Regression

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Salary_Data.csv")
df4
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df4.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
plt.scatter(df4["YearsExperience"],df4["Salary"])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
x = df4[["YearsExperience"]]
y = df4["Salary"]

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree = 2)
pf.fit(x)
pf.transform(x)
# Out:
# array([[  1.  ,   1.1 ,   1.21],
#        [  1.  ,   1.3 ,   1.69],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.2 ,   4.84],
#        [  1.  ,   2.9 ,   8.41],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.7 ,  13.69],
#        [  1.  ,   3.9 ,  15.21],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.1 ,  16.81],
#        [  1.  ,   4.5 ,  20.25],
#        [  1.  ,   4.9 ,  24.01],
#        [  1.  ,   5.1 ,  26.01],
#        [  1.  ,   5.3 ,  28.09],
#        [  1.  ,   5.9 ,  34.81],
#        [  1.  ,   6.  ,  36.  ],
#        [  1.  ,   6.8 ,  46.24],
#        [  1.  ,   7.1 ,  50.41],
#        [  1.  ,   7.9 ,  62.41],
#        [  1.  ,   8.2 ,  67.24],
#        [  1.  ,   8.7 ,  75.69],
#        [  1.  ,   9.  ,  81.  ],
#        [  1.  ,   9.5 ,  90.25],
#        [  1.  ,   9.6 ,  92.16],
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
#pf.fit(y)
x =pf.transform(x)

# %%
x
# Out:
# array([[  1.  ,   1.1 ,   1.21],
#        [  1.  ,   1.3 ,   1.69],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.2 ,   4.84],
#        [  1.  ,   2.9 ,   8.41],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.2 ,  10.24],
#        [  1.  ,   3.7 ,  13.69],
#        [  1.  ,   3.9 ,  15.21],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.  ,  16.  ],
#        [  1.  ,   4.1 ,  16.81],
#        [  1.  ,   4.5 ,  20.25],
#        [  1.  ,   4.9 ,  24.01],
#        [  1.  ,   5.1 ,  26.01],
#        [  1.  ,   5.3 ,  28.09],
#        [  1.  ,   5.9 ,  34.81],
#        [  1.  ,   6.  ,  36.  ],
#        [  1.  ,   6.8 ,  46.24],
#        [  1.  ,   7.1 ,  50.41],
#        [  1.  ,   7.9 ,  62.41],
#        [  1.  ,   8.2 ,  67.24],
#        [  1.  ,   8.7 ,  75.69],
#        [  1.  ,   9.  ,  81.  ],
#        [  1.  ,   9.5 ,  90.25],
#        [  1.  ,   9.6 ,  92.16],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prd = lr.predict(x)

# %%
plt.scatter(df4["YearsExperience"],df4["Salary"])
plt.plot(df4["YearsExperience"], prd, c ='red')
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.legend(["org","prd"])
plt.show()

# %%
test = pf.transform([[4.5]])
test
# Out:
# C:\Users\Ali Shah\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[ 1.  ,  4.5 , 20.25]])

# %%
lr.predict(test)
# Out:
# array([67159.0850906])

# %% [raw]
# What is Cost Function

# %%
Regression Cost Function

# %%
Regulization Technique

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df5 = pd.read_csv(r"https://raw.githubusercontent.com/ywchiu/riii/refs/heads/master/data/house-prices.csv")

# %%
df5.head(3)
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East

# %%
x = df5.iloc[:,:-1]
y = df5["Price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size =0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lr.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 lr.coef_
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
plt.bar(x.columns,lr.coef_)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.bar(x.columns,lr.coef_)
#       2 plt.show()
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
x.columns
# Out:
# Index(['Home', 'Price', 'SqFt', 'Bedrooms', 'Bathrooms', 'Offers', 'Brick'], dtype='object')

# %%
Lasso

# %%
la = Lasso(alpha=0.5)
la.fit(x_train, y_train)
la.score(x_test,y_test)*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8084\2868924067.py in ?()
#       1 la = Lasso(alpha=0.5)
# ----> 2 la.fit(x_train, y_train)
#       3 la.score(x_test,y_test)*100
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py in ?(self, X, y, sample_weight, check_input)
#     978         # We expect X and y to be float64 or float32 Fortran ordered arrays
#     979         # when bypassing checks
# ...

# %%
Ridge

# %%
ri = Ridge(alpha =10)
ri.fit(x_train,y_train)
ri.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8084\154049458.py in ?()
#       1 ri = Ridge(alpha =10)
# ----> 2 ri.fit(x_train,y_train)
#       3 ri.score(x_test,y_test)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_ridge.py in ?(self, X, y, sample_weight)
#    1235             Fitted estimator.
#    1236         """
#    1237         _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_squared_error(y_test,lr.predict(x_test))
mean_absolute_error(y_test,lr.predict(x_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8084\201412162.py in ?()
# ----> 1 mean_squared_error(y_test,lr.predict(x_test))
#       2 mean_absolute_error(y_test,lr.predict(x_test))
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
#     293         -------
#     294         C : array, shape (n_samples,)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X)
#     273     def _decision_function(self, X):
#     274         check_is_fitted(self)
#     275
# --> 276         X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     277         coef_ = self.coef_
# ...
